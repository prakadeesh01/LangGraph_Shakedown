# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool
from pydantic import BaseModel, Field
from langgraph.graph import MessagesState,StateGraph, END
from langgraph.prebuilt import ToolNode
from langchain_core.messages import HumanMessage
# Out:
# C:\Users\pragi\AppData\Local\Temp\ipykernel_15792\2175221225.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="llama-3.3-70b-versatile")

# %%
tavily_tool = TavilySearchResults()
# Out:
# C:\Users\pragi\AppData\Local\Temp\ipykernel_15792\583234793.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tavily_tool = TavilySearchResults()

# %%
@tool
def get_city_details(prompt):
    "Should do a web search to find the required city details"
    response = tavily_tool.invoke(prompt)
    return response

# %%
tools = [get_city_details]

# %%
model_with_tools = llm.bind_tools(tools)

# %%
class CityDetails(BaseModel):
    """Respond to the user with this"""
    state_name: str = Field(description="State name of the city")
    state_capital: str = Field(description="State capital of the city")
    country_name: str = Field(description="Country name of the city")
    country_capital: str = Field(description="Country capital of the city")

# %%
# Inherit 'messages' key from MessagesState, which is a list of chat messages
class AgentState(MessagesState):
    # Final structured response from the agent
    final_response: CityDetails

# %%
model_with_structured_output = llm.with_structured_output(CityDetails)

# %%
def call_model(state: AgentState):
    print(f" this is 01 input from call model {state}")
    response = model_with_tools.invoke(state['messages'])
    print(f"this is 02 response from call model  {response}")
    # We return a list, because this will get added to the existing list
    return {"messages": [response]}

# %%
def should_continue(state: AgentState):
    messages = state["messages"]
    last_message = messages[-1]
    
    # If there is no function call, then we respond to the user
    if not last_message.tool_calls:
        return "respond"
    # Otherwise if there is, we continue with the tool
    else:
        return "continue"

# %%
def respond(state: AgentState):
    print(f"here is 03 state from respond {state}")
    response = model_with_structured_output.invoke([HumanMessage(content=state['messages'][-1].content)])
    # We return the final answer
    print(f"this is 04 response from respond{response}")
    return {"final_response": response}

# %%
# Define a new graph
workflow = StateGraph(AgentState)

# Define the two nodes we will cycle between
workflow.add_node("llm", call_model)
workflow.add_node("tools", ToolNode(tools))
workflow.add_node("respond", respond)


# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("llm")

# We now add a conditional edge
workflow.add_conditional_edges(
    "llm",
    
    should_continue,
    {
        "continue": "tools",
        "respond": "respond",
    },
)

workflow.add_edge("tools", "llm")
workflow.add_edge("respond", END)
graph = workflow.compile()

# %%
from IPython.display import Image, display
# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
answer = graph.invoke(input={"messages": [("human", "Tell me about the city details for gwalior?")]})['final_response']
# Out:
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for gwalior?', additional_kwargs={}, response_metadata={}, id='bca1f5f8-153d-4988-9df7-de230ae9ce1e')]}
# this is 02 response from call model  content='' additional_kwargs={'tool_calls': [{'id': 'mcqjdjy8e', 'function': {'arguments': '{"prompt":"gwalior city details"}', 'name': 'get_city_details'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 233, 'total_tokens': 252, 'completion_time': 0.047404301, 'completion_tokens_details': None, 'prompt_time': 0.011673038, 'prompt_tokens_details': None, 'queue_time': 0.04163918, 'total_time': 0.059077339}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f0ad0-ea4a-78f3-97ee-3c25c43998d0-0' tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'gwalior city details'}, 'id': 'mcqjdjy8e', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 233, 'output_tokens': 19, 'total_tokens': 252}
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for gwalior?', additional_kwargs={}, response_metadata={}, id='bca1f5f8-153d-4988-9df7-de230ae9ce1e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'mcqjdjy8e', 'function': {'arguments': '{"prompt":"gwalior city details"}', 'name': 'get_city_details'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 233, 'total_tokens': 252, 'completion_time': 0.047404301, 'completion_tokens_details': None, 'prompt_time': 0.011673038, 'prompt_tokens_details': None, 'queue_time': 0.04163918, 'total_time': 0.059077339}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f0ad0-ea4a-78f3-97ee-3c25c43998d0-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'gwalior city details'}, 'id': 'mcqjdjy8e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 233, 'output_tokens': 19, 'total_tokens': 252}), ToolMessage(content='[{"title": "Gwalior - Wikipedia", "url": "https://en.wikipedia.org/wiki/Gwalior", "content": "Gwalior (pronounced (/wiki/Help:IPA/Hindi_and_Urdu \\"Help:IPA/Hindi and Urdu\\") ⓘ) is the fourth largest city of the Indian state of Madhya Pradesh where it serves as the capital and the administrative headquarters of the eponymous district and division. It is an important cultural, industrial, sports and political centre. Known as the music city of India, it is home to the oldest musical gharana of the Indian subcontinent and of the earliest known epigraphical inscription that uses the number 0 (zero) as part of the Hindu numeral system. The grand historic city and its fortress have been ruled by several Indian kingdoms from the Alchon Huns to the Gurjara Pratihara and Kachchhapaghata dynasties. Later it fell into the hands of the Delhi Sultanate before passing on to their vassals, the [...] | Government | |\\n| • Type | Municipal Corporation |\\n| • Body | Gwalior Municipal Corporation (GMC) |\\n| • Mayor | Shobha Sikarwar |\\n| • Administrator | Ruchika Chauhan IAS |\\n| Area  | |\\n| • Metropolis | 414 km2 (160 sq mi) |\\n| Elevation | 247.04 m (810.5 ft) |\\n| Population (2011 census) | |\\n| • Metropolis | 2,032,036 |\\n| • Density | 5,478/km2 (14,190/sq mi) |\\n| • Metro | 1,273,792 |\\n| • Population rank | 46th |\\n| Demonym(s) | Gwaliorites, Gwaliori |\\n| Language | |\\n| • Official | Hindi, |\\n| • Other | Bundeli, Marathi |\\n| Time zone | UTC+5:30 (IST) |\\n| PIN | 474001 to 474055 |\\n| Telephone code | 0751 |\\n| Vehicle registration | MP-07 |\\n| Sex ratio | 862 ♂/♀ |\\n| Literacy | 87.14% |\\n| Website | gwalior.nic.in | [...] | Gwalior | |\\n --- |\\n| Metropolis | |\\n| Gwalior Fort  Teli ka Mandir  Siddhachal Caves  Sasbahu Temple  Durbar Hall  Jai Vilas Mahal  Tomb of Mohammad Ghaus and Tansen  Maharaj Bada Shopping District | |\\n| Coat of arms of Gwalior Coat of arms | |\\n| Nicknames: The City of Music, Capital of Hindustani Music, The Royal City of Madhya Pradesh | |\\n| Gwalior is located in Madhya Pradesh Gwalior  Gwalior   Show map of Madhya Pradesh  Gwalior is located in India Gwalior  Gwalior   Show map of India | |\\n| Coordinates: 26°12′45″N 78°10′39″E\ufeff / \ufeff26.2125°N 78.1775°E\ufeff / 26.2125; 78.1775_region:IN-MP) | |\\n| Country | India |\\n| State | Madhya Pradesh |\\n| Region | Gwalior Chambal |\\n| District | Gwalior |\\n| Founded by | Suraj Sen |\\n| Government | |\\n| • Type | Municipal Corporation |", "score": 0.8446273}, {"title": "Profile | District Gwalior, Government of Madhya Pradesh | India", "url": "https://gwalior.nic.in/en/history", "content": "Gwalior’s history is traced back to a legend in 8th century AD when a chief tain known as Suraj Sen was struck by a deadly disease and cured by a hermit-saint Gwalipa. As a gratitude for t ...
# this is 02 response from call model  content='Gwalior is a city in the Indian state of Madhya Pradesh, known for its rich history and cultural significance. The city has been ruled by various dynasties, including the Alchon Huns, Gurjara Pratihara, and Kachchhapaghata, and has been an important center for music, poetry, and art. The city is home to several historical monuments, including the Gwalior Fort, Teli ka Mandir, and the Tomb of Mohammad Ghaus and Tansen. The city has a population of over 2 million people and is an important cultural and economic hub in the region.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 130, 'prompt_tokens': 2767, 'total_tokens': 2897, 'completion_time': 0.273128753, 'completion_tokens_details': None, 'prompt_time': 0.224482209, 'prompt_tokens_details': None, 'queue_time': 0.041786721, 'total_time': 0.497610962}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f0ad0-f99f-7ef0-9231-76e305b6494b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2767, 'output_tokens': 130, 'total_tokens': 2897}
# here is 03 state from respond {'messages': [HumanMessage(content='Tell me about the city details for gwalior?', additional_kwargs={}, response_metadata={}, id='bca1f5f8-153d-4988-9df7-de230ae9ce1e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'mcqjdjy8e', 'function': {'arguments': '{"prompt":"gwalior city details"}', 'name': 'get_city_details'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 233, 'total_tokens': 252, 'completion_time': 0.047404301, 'completion_tokens_details': None, 'prompt_time': 0.011673038, 'prompt_tokens_details': None, 'queue_time': 0.04163918, 'total_time': 0.059077339}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f0ad0-ea4a-78f3-97ee-3c25c43998d0-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'gwalior city details'}, 'id': 'mcqjdjy8e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 233, 'output_tokens': 19, 'total_tokens': 252}), ToolMessage(content='[{"title": "Gwalior - Wikipedia", "url": "https://en.wikipedia.org/wiki/Gwalior", "content": "Gwalior (pronounced (/wiki/Help:IPA/Hindi_and_Urdu \\"Help:IPA/Hindi and Urdu\\") ⓘ) is the fourth largest city of the Indian state of Madhya Pradesh where it serves as the capital and the administrative headquarters of the eponymous district and division. It is an important cultural, industrial, sports and political centre. Known as the music city of India, it is home to the oldest musical gharana of the Indian subcontinent and of the earliest known epigraphical inscription that uses the number 0 (zero) as part of the Hindu numeral system. The grand historic city and its fortress have been ruled by several Indian kingdoms from the Alchon Huns to the Gurjara Pratihara and Kachchhapaghata dynasties. Later it fell into the hands of the Delhi Sultanate before passing on to their vassals, the [...] | Government | |\\n| • Type | Municipal Corporation |\\n| • Body | Gwalior Municipal Corporation (GMC) |\\n| • Mayor | Shobha Sikarwar |\\n| • Administrator | Ruchika Chauhan IAS |\\n| Area  | |\\n| • Metropolis | 414 km2 (160 sq mi) |\\n| Elevation | 247.04 m (810.5 ft) |\\n| Population (2011 census) | |\\n| • Metropolis | 2,032,036 |\\n| • Density | 5,478/km2 (14,190/sq mi) |\\n| • Metro | 1,273,792 |\\n| • Population rank | 46th |\\n| Demonym(s) | Gwaliorites, Gwaliori |\\n| Language | |\\n| • Official | Hindi, |\\n| • Other | Bundeli, Marathi |\\n| Time zone | UTC+5:30 (IST) |\\n| PIN | 474001 to 474055 |\\n| Telephone code | 0751 |\\n| Vehicle registration | MP-07 |\\n| Sex ratio | 862 ♂/♀ |\\n| Literacy | 87.14% |\\n| Website | gwalior.nic.in | [...] | Gwalior | |\\n --- |\\n| Metropolis | |\\n| Gwalior Fort  Teli ka Mandir  Siddhachal Caves  Sasbahu Temple  Durbar Hall  Jai Vilas Mahal  Tomb of Mohammad Ghaus and Tansen  Maharaj Bada Shopping District | |\\n| Coat of arms of Gwalior Coat of arms | |\\n| Nicknames: The City of Music, Capital of Hindustani Music, The Royal City of Madhya Pradesh | |\\n| Gwalior is located in Madhya Pradesh Gwalior  Gwalior   Show map of Madhya Pradesh  Gwalior is located in India Gwalior  Gwalior   Show map of India | |\\n| Coordinates: 26°12′45″N 78°10′39″E\ufeff / \ufeff26.2125°N 78.1775°E\ufeff / 26.2125; 78.1775_region:IN-MP) | |\\n| Country | India |\\n| State | Madhya Pradesh |\\n| Region | Gwalior Chambal |\\n| District | Gwalior |\\n| Founded by | Suraj Sen |\\n| Government | |\\n| • Type | Municipal Corporation |", "score": 0.8446273}, {"title": "Profile | District Gwalior, Government of Madhya Pradesh | India", "url": "https://gwalior.nic.in/en/history", "content": "Gwalior’s history is traced back to a legend in 8th century AD when a chief tain known as Suraj Sen was struck by a deadly disease and cured by a hermit-saint Gwalipa. As a gratitude for that  ...
# this is 04 response from respondstate_name='Madhya Pradesh' state_capital='Bhopal' country_name='India' country_capital='New Delhi'

# %%
answer
# Out:
# CityDetails(state_name='Madhya Pradesh', state_capital='Bhopal', country_name='India', country_capital='New Delhi')
